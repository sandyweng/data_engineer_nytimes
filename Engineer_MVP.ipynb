# %% [markdown]
# # New York Times Topic Modeling

# %% [markdown]
# Pipeline:
#
# Data Ingestion - API call to MongoDB (did this manually to download 100k+ articles for analysis)
#
#     - still need to do cron for data ingestion automation to make api call everyday for most shared stories
#
# Data Processing - worked on large dataset for data cleaning and NLP
#
#     - need to create functions for text preprocessing and NLP for most shared stories
#
# Deployment - created Streamlit app that output 10 topics for Opinions section of large dataset
#
#     -need to create NMF pipeline for most shared stories to deploy to Streamlit

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The bar graph shows that most articles are domestic news. I will do topic modeling on US, World, and Opinion sections to compare the topics from 2019 to May 2021.

# %% [markdown]
# ![image.png](attachment:image.png)
